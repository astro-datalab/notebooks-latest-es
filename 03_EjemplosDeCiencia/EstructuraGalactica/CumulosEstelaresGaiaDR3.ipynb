# %%
__nbid__ = '0017'
__author__ = 'Leah Fulmer, Astro Data Lab Team <datalab@noirlab.edu>'
__version__ = '20250818' # yyyymmdd
__datasets__ = ['gaia_dr3']
__keywords__ = ['star clusters', 'stars', 'proper motions', 'parallax', 'plot:cmd', 'plot:quiver', 'plot:animation']

# %% [markdown]
# # Visualizando Cúmulos Estelares en Gaia DR3
# *Leah Fulmer y el equipo de Astro Data Lab*

# %% [markdown]
# ### Tabla de contenido
# * [Objetivos y resumen del cuaderno](#goals)
# * [Avisos legales y atribuciones](#attribution)
# * [Importaciones y configuración](#import)
# * [Autenticación](#auth)
# * [Configuración de una consulta básica](#query)
# * [Visualización estacionaria](#stationary)
# * [Animación de paralaje](#animation)
# * [Aplicando ambas visualizaciones](#both)

# %% [markdown]
# <a class="anchor" id="goals"></a>
# # Objetivos
# * Definir una función que consulte el catálogo Gaia DR3 por nombre de cúmulo estelar
# * Visualizar movimientos propios con un gráfico de flechas (quiver)
# * Visualizar el paralaje con gráficos animados

# %% [markdown]
# # Resumen
# Este Notebook ofrece un ejemplo de una consulta de Búsqueda de Cono del catálogo Gaia DR3. Dado un objeto y un radio, este Notebook consultará un área del cielo centrada en el objeto dado y que se extiende hasta el radio especificado. Luego ofrecerá varias visualizaciones de los datos consultados.

# %% [markdown]
# <a class="anchor" id="attribution"></a>
# # Avisos Legales y atribuciones
#
# Avisos Legales
# -----------
# Tome en cuenta que usar el Astro Data Lab constituye un acuerdo con nuestros [Avisos Legales](https://datalab.noirlab.edu/disclaimers.php) mínimos.
#
# Reconocimientos
# ---------------
# Si ud. usa el **Astro Data Lab** en sus publicaciones de investigación, por favor incluya el siguiente texto en la sección de Reconocimientos de su publicaciones:
#
# _Esta investigación utiliza servicios de datos proveeidos por el Astro Data Lab, el cual es parte del Programa "Community Science and Data Center" (CSDC) (Centro de Ciencia Comunitaria y Datos) del NSF NOIRLab. NOIRLab es operado por la "Association of Universities for Research in Astronomy (AURA), Inc."(Asociación de Universidaddes para la Investigación en Astronomía, Inc.), bajo un acuerdo de cooperación con la "U.S. National Science Foundation" (Fundación Nacional de Ciencia de los EE. UU.)._
#
# Si utiliza **SPARCL junto con la plataforma de Astro Data Lab** (por medio de JupyterLab, línea de comando o interfaz de la web) en su publicación de investigación, por favor incluya el siguiente texto en la sección de Reconocimientos de su publicaciones:
#
# _Esta investigación utiliza servicios o datos proporcionados por el "SPectra Analysis and Retrievable Catalog Lab" (SPARCL) (Laboratorio de Análisis y Catálogo Recuperable de Espectros) y el Astro Data Lab, ambos pertenecientes al Programa "Community Science and Data Center" (CSDC) (Centro de Ciencia Comunitaria y Datos) de NSF NOIRLab. NOIRLab es operado por la "Association of Universities for Research in Astronomy (AURA), Inc." (Asociación de Universidades para la Investigación en Astronomía, Inc.), bajo un acuerdo de cooperación con la "U.S. National Science Foundation" (Fundación Nacional de Ciencia de los EE. UU.)._
#
# En cualquiera de los casos, **por favor cite las siguientes publicaciones**:
#
# * Publicación del concepto de Data Lab: Fitzpatrick et al., "The NOAO Data Laboratory: a conceptual overview", SPIE, 9149, 2014, https://doi.org/10.1117/12.2057445
#
# * Descripción general del Astro Data Lab: Nikutta et al., "Data Lab - A Community Science Platform", Astronomy and Computing, 33, 2020, https://doi.org/10.1016/j.ascom.2020.100411.
#
# Si hace referencia al Jupyterlab / Jupyter notebooks de Data Lab, cite:
#
# * Juneau et al., "Jupyter-Enabled Astrophysical Analysis Using Data-Proximate Computing Platforms", CiSE, 23, 15, 2021, https://doi.org/10.1109/MCSE.2021.3057097.
#
# Si publica en una revista de la AAS, agregue también la palabra clave `\facility{Astro Data Lab}`
#
# Y si está usando SPARCL, por vor agregue también `\software{SPARCL}` y cite:
#
# * Juneau et al., "SPARCL: SPectra Analysis and Retrievable Catalog Lab", Conference Proceedings for ADASS XXXIII, 2024
# https://doi.org/10.48550/arXiv.2401.05576.
#
# La biblioteca de NOIRLab mantiene [listas de reconocimientos apropiados](https://noirlab.edu/science/about/scientific-acknowledgments) para usar cuando se hacen publicaciones utilizando los recursos, servicios o datos del Laboratorio.
#
# ---- **Versión en Inglés** ----
#
# # Disclaimer & attribution
#
# Disclaimers
# -----------
# Note that using the Astro Data Lab constitutes your agreement with our minimal [Disclaimers](https://datalab.noirlab.edu/disclaimers.php).
#
# Acknowledgments
# ---------------
# If you use **Astro Data Lab** in your published research, please include the text in your paper's Acknowledgments section:
#
# _This research uses services or data provided by the Astro Data Lab, which is part of the Community Science and Data Center (CSDC) Program of NSF NOIRLab. NOIRLab is operated by the Association of Universities for Research in Astronomy (AURA), Inc. under a cooperative agreement with the U.S. National Science Foundation._
#
# If you use **SPARCL jointly with the Astro Data Lab platform** (via JupyterLab, command-line, or web interface) in your published research, please include this text below in your paper's Acknowledgments section:
#
# _This research uses services or data provided by the SPectra Analysis and Retrievable Catalog Lab (SPARCL) and the Astro Data Lab, which are both part of the Community Science and Data Center (CSDC) Program of NSF NOIRLab. NOIRLab is operated by the Association of Universities for Research in Astronomy (AURA), Inc. under a cooperative agreement with the U.S. National Science Foundation._
#
# In either case **please cite the following papers**:
#
# * Data Lab concept paper: Fitzpatrick et al., "The NOAO Data Laboratory: a conceptual overview", SPIE, 9149, 2014, https://doi.org/10.1117/12.2057445
#
# * Astro Data Lab overview: Nikutta et al., "Data Lab - A Community Science Platform", Astronomy and Computing, 33, 2020, https://doi.org/10.1016/j.ascom.2020.100411
#
# If you are referring to the Data Lab JupyterLab / Jupyter Notebooks, cite:
#
# * Juneau et al., "Jupyter-Enabled Astrophysical Analysis Using Data-Proximate Computing Platforms", CiSE, 23, 15, 2021, https://doi.org/10.1109/MCSE.2021.3057097
#
# If publishing in a AAS journal, also add the keyword: `\facility{Astro Data Lab}`
#
# And if you are using SPARCL, please also add `\software{SPARCL}` and cite:
#
# * Juneau et al., "SPARCL: SPectra Analysis and Retrievable Catalog Lab", Conference Proceedings for ADASS XXXIII, 2024
# https://doi.org/10.48550/arXiv.2401.05576
#
# The NOIRLab Library maintains [lists of proper acknowledgments](https://noirlab.edu/science/about/scientific-acknowledgments) to use when publishing papers using the Lab's facilities, data, or services.

# %% [markdown]
# <a class="anchor" id="import"></a>
# # Importaciones y Configuración

# %%
# Importaciones para servicios de animación
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord, CartesianRepresentation, SphericalRepresentation, matrix_utilities

from matplotlib import cm, colors, pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# Importaciones desde el cuaderno de Data Lab
from getpass import getpass

from dl.helpers.utils import convert
from dl import authClient as ac, queryClient as qc

# %matplotlib inline

# %% [markdown]
# <a class="anchor" id="auth"></a>
# # Autenticación
# Se puede acceder a gran parte de la funcionalidad de Data Lab sin iniciar sesión explícitamente (el servicio utiliza un inicio de sesión anónimo). Sin embargo, algunas funciones, como guardar los resultados de las consultas en el espacio de almacenamiento virtual, requieren iniciar sesión (es decir, necesitará una cuenta de usuario registrada).
#
# Si necesita iniciar sesión en Data Lab, descomente la celda a continuación y ejecútela:

# %%
#token = ac.login(input("Ingrese su nombre de usuario: (+ENTER) "),getpass("Ingrese su contraseña:: (+ENTER) "))
#ac.whoAmI()

# %% [markdown]
# <a class="anchor" id="query"></a>
# # Configurando una consulta básica
#
# La base de datos se llama **gaia_dr3** e incluye varias tablas. Exploramos las tablas disponibles a continuación.

# %%
# Construir la consulta como cadena
query = "SELECT * FROM gaia_dr3.gaia_source LIMIT 1"

# Enviar la consulta
response = qc.query(sql=query, fmt='csv')

# Convertir la salida de cadena a un DataFrame de pandas
df_init = convert(response,'pandas')

# Para ver las columnas disponibles, incluir el siguiente comando
df_init.columns
# Out:
# Index(['b', 'dec', 'ecl_lat', 'ecl_lon', 'l', 'parallax', 'phot_bp_mean_flux',
#        'phot_g_mean_flux', 'phot_rp_mean_flux', 'pmdec',
#        ...
#        'in_galaxy_candidates', 'in_qso_candidates', 'designation',
#        'libname_gspphot', 'phot_variable_flag', 'astrometric_params_solved',
#        'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'phot_proc_mode',
#        'rv_method_used'],
#       dtype='object', length=156)

# %%
# Escribir una consulta que devuelva todas las estrellas alrededor de un objeto particular hasta un radio particular 

def consulta_de_entrada(object_name, radius_deg):
    # SkyCoord.from_name devuelve las coordenadas de un objeto dado su nombre como cadena
    c = SkyCoord.from_name(object_name)
    
    # Construir una consulta de Búsqueda Cónica (Cone Search)
    query = """SELECT * FROM gaia_dr3.gaia_source 
            WHERE (q3c_radial_query(ra, dec, {0}, {1}, %s)
            AND NOT parallax='Nan')""".format(c.ra.value,c.dec.value) % (radius_deg)
    
    # Enviar la consulta
    response = qc.query(sql=query, fmt='csv')
    
    # Convertir la salida a un DataFrame de pandas
    df = convert(response,'pandas')
    
    # Comprobar el número de objetos en tu consulta
    print("La consulta de %s contiene %s objetos." % (object_name, len(df)))
    
    # Devolver el DataFrame de salida
    return df

# %%
# ¡Elige tu objeto favorito!

# Definir un objeto
object_queried = "NGC 6281"

# Definir un radio
radius = 0.5

# Ejecutar la función que devuelve un DataFrame consultado
df = consulta_de_entrada(object_queried, radius)
# Out:
# La consulta de NGC 6281 contiene 205028 objetos.

# %%
# Definir variables a partir del DataFrame
# Hacerlo dentro de una función hace muy simple redefinirlas más adelante
def define_variables (df):
    ra, dec = df["ra"], df["dec"]
    ra_rad, dec_rad = np.radians(ra), np.radians(dec)
    pmra, pmdec = df["pmra"], df["pmdec"]
    parallax = df['parallax']
    g, g_bp = df["phot_g_mean_mag"], df["phot_g_mean_mag"]-df["phot_bp_mean_mag"]
    return ra, dec, ra_rad, dec_rad, pmra, pmdec, parallax, g, g_bp

# Ejecutar la función que define variables a partir del DataFrame
ra, dec, ra_rad, dec_rad, pmra, pmdec, parallax, g, g_bp = define_variables(df)

# %% [markdown]
# <a class="anchor" id="stationary"></a>
# # Visualización estacionaria:

# %%
# Escribir una función que genere gráficos espaciales y de color-magnitud para tu objeto muestreado
def panel_plot(ra, dec, pmra, pmdec, color, mag):
    fig = plt.figure(figsize=(26,8))
    
    # Un gráfico espacial simple
    ax1 = fig.add_subplot(131)
    ax1.scatter(ra, dec, marker='.', alpha= 1/np.power(len(df), 0.1))
    ax1.set_title("Gráfico espacial",fontsize=10)
    ax1.set_xlabel("AR",fontsize=10)
    ax1.set_ylabel("Declinación",fontsize=10)
    
    # Un gráfico de flechas (gráfico espacial con flechas que describen el movimiento propio de cada objeto)
    ax2 = fig.add_subplot(132)
    ax2.quiver(ra, dec, pmra, pmdec)
    ax2.set_title("Movimientos propios",fontsize=10)
    ax2.set_xlabel("AR",fontsize=10)
    ax2.set_ylabel("Declinación",fontsize=10)
    
    # Un diagrama color-magnitud que muestra la densidad de objetos
    ax3 = fig.add_subplot(133)
    im3 = ax3.hexbin(g_bp, g, bins='log', cmap=plt.cm.viridis, mincnt=1)
    ax3.set_ylim(max(g), min(g))
    ax3.set_title("Diagrama color-magnitud",fontsize=10)
    ax3.set_xlabel("Color Gaia G-BP",fontsize=10)
    ax3.set_ylabel("Magnitud Gaia G",fontsize=10)
    cb = plt.colorbar(im3,label='log(N)')

# %% [markdown]
# <a class="anchor" id="animation"></a>
# # Animación de paralaje:
# Código basado en el de Eric Tollerud vía http://nbviewer.jupyter.org/gist/eteq/02a0065f15da3b3d8c2a9dea146a2a14/parallax_GaiaDR2.ipynb
#
# Inspirado por James Davenport vía https://twitter.com/jradavenport/status/976205932274245632

# %%
# Convertir variables a objeto SkyCoord e imponer límites en la salida

def convert_to_skycoord (g, ra_rad, dec_rad, parallax, dist1, dist2):
    # Definir variables como un arreglo de numpy y objeto SkyCoord
    # Nota: El objeto SkyCoord contiene datos de AR, Dec y paralaje
    mag = np.array(g)
    scnow = SkyCoord(np.array(ra_rad) * u.rad, np.array(dec_rad) * u.rad, 
                 distance=(np.array(parallax)*u.mas).to(u.pc, u.parallax()))

    # Crear una "máscara" con distintos umbrales de datos (aquí dependiendo de magnitud y distancia)
    msk = (mag < 16)  & (scnow.distance > dist1*u.pc) & (scnow.distance < dist2*u.pc)
    
    # Aplicar umbrales de datos a la magnitud dada y objetos SkyCoord
    mag = mag[msk]
    scnow = scnow[msk]
    
    # Imprimir el nuevo conteo de objetos después de aplicar los umbrales
    print('Después de aplicar los umbrales, esta consulta contiene %s objetos.' % (len(scnow)))
    
    # Retornar las variables definidas
    return mag, msk, scnow
    
mag, msk, scnow = convert_to_skycoord(g, ra_rad, dec_rad, parallax, 1e2, 9e2)
# Out:
# Después de aplicar los umbrales, esta consulta contiene 1094 objetos.

# %%
# Hacer una versión especial del mapa de color viridis que vaya a un amarillo más oscuro al final. 
# Esto hace que sea más fácil ver puntos pequeños en un fondo blanco.
newvhsv = colors.rgb_to_hsv(cm.viridis.colors)
newvhsv[:,-1] = np.minimum(newvhsv[:,-1], .88)
darker_vidiris = colors.ListedColormap(colors.hsv_to_rgb(newvhsv))

# Definir una función para representar magnitud con tamaño del marcador y distancia con color del marcador
# Aquí el morado simbolizará los objetos más cercanos, y el amarillo simbolizará los más lejanos
def mag_to_size(mag):
    unity_rescaled_mag = (np.max(mag) - mag)/np.ptp(mag)
    return 40*unity_rescaled_mag**2+2

# Guardar estos argumentos de visualización como 'scatkwargs'
scatkwargs = dict(s=mag_to_size(mag), alpha=.9, c=scnow.distance.value, cmap=darker_vidiris)

# %%
# Escribir una función para animar la paralaje de tu muestra

# La amplitud describe la distancia que moverán los marcadores al representar la paralaje.
amplitude = 0.6*u.lightyear
repr0 = scnow.barycentrictrueecliptic.cartesian

def animfunc(phase, eclcart_to_spherical, centerstr, ylims, ax):
    
    # Convertir de coordenadas cartesianas a esféricas
    drepr = CartesianRepresentation([np.cos(phase),np.sin(phase),0]*amplitude)
    rep = repr0 + drepr
    srep = eclcart_to_spherical(rep)
    
    # Crear y definir la estética de la gráfica
    ax.cla()
    ax.set_title(f'Centro={centerstr}, Semieje Mayor de la Tierra={amplitude} \n')
    # ax.scatter(srep.lon.rad, 90-srep.lat.deg, **scatkwargs)
    ax.scatter(80.2+srep.lon.rad, 90-srep.lat.deg, **scatkwargs)
    ax.set_ylim(*ylims)
    ax.set_yticks(np.linspace(*ax.get_ylim(), 5)[1:])
    ax.set_yticklabels(['{}'.format(int(90-yl)) for yl in ax.get_yticks()])
    ax.grid(alpha=0.5)

# %%
# Centrar la visualización en un objeto dado
def eclcart_to_spherical3(rep):
    icrsrep = SkyCoord(scnow.barycentrictrueecliptic.realize_frame(rep)).icrs.cartesian   
    rot1 = matrix_utilities.rotation_matrix(object_name.ra, 'z')
    rot2 = matrix_utilities.rotation_matrix(90*u.deg-object_name.dec, 'y')
    return icrsrep.transform(rot2 @ rot1).represent_as(SphericalRepresentation)

# %% [markdown]
# <a class="anchor" id="both"></a>
# # Aplicando ambas visualizaciones:

# %%
# Llamar a la gráfica estacionaria
panel_plot(scnow.ra, scnow.dec, pmra[msk], pmdec[msk], g_bp[msk], g[msk])

# %%
# Llamar a la animación de paralaje
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(projection='polar')
object_name = SkyCoord.from_name(object_queried)
centerstr3 = object_queried
ylims3 = (0, radius)

anim3 = animation.FuncAnimation(fig, animfunc, np.linspace(0, 2*np.pi, 30),
                                fargs=(eclcart_to_spherical3, centerstr3, ylims3, ax), 
                                interval=50)

plt.close(fig)
HTML(anim3.to_html5_video())
# Out:
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# ¡Elige tu segundo objeto favorito!

# Definir objeto y radio
object_queried = "NGC 6397"
radius = 0.1

# Enviar consulta
df = consulta_de_entrada(object_queried, radius)
# Out:
# La consulta de NGC 6397 contiene 20352 objetos.

# %%
# Definir variables
ra, dec, ra_rad, dec_rad, pmra, pmdec, parallax, g, g_bp = define_variables(df)

# Aplicar umbrales
mag, msk, scnow = convert_to_skycoord(g, ra_rad, dec_rad, parallax, 1e3, 3e3)

# Definir parámetros de visualización
scatkwargs = dict(s=mag_to_size(mag), alpha=.9, c=scnow.distance.value, cmap=darker_vidiris)
amplitude = 0.6*u.lightyear
repr0 = scnow.barycentrictrueecliptic.cartesian
# Out:
# Después de aplicar los umbrales, esta consulta contiene 888 objetos.

# %%
# Llamar a la gráfica estacionaria
panel_plot(scnow.ra, scnow.dec, pmra[msk], pmdec[msk], g_bp[msk], g[msk])

# %%
# Llamar a la animación de paralaje
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(projection='polar')
object_name = SkyCoord.from_name(object_queried)
centerstr3 = object_queried
ylims3 = (0, radius)

anim3 = animation.FuncAnimation(fig, animfunc, np.linspace(0, 2*np.pi, 30),
                                fargs=(eclcart_to_spherical3, centerstr3, ylims3, ax), 
                                interval=50)

plt.close(fig)
HTML(anim3.to_html5_video())
# Out:
# <video width="800" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...
